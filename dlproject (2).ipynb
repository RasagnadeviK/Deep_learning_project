# %%
import os 
import cv2
import os 
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import keras 
from keras.callbacks import EarlyStopping, ModelCheckpoint
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report

# Read Data
def data(dataset_path):
    images = []
    labels = []
    for subfolder in os.listdir(dataset_path):
        subfolder_path = os.path.join(dataset_path, subfolder)
        if not os.path.isdir(subfolder_path):
            continue
        for image_filename in os.listdir(subfolder_path):
            if image_filename.endswith(".jpg"):
                image_path = os.path.join(subfolder_path, image_filename)
                images.append(image_path)
                labels.append(subfolder)
    df = pd.DataFrame({'image': images, 'label': labels})
    return df

def create_data_generators(train, test, val):
    image_size = (224, 224)
    batch_size = 32
    datagen = ImageDataGenerator(rescale=1./255)

    train_generator = datagen.flow_from_dataframe(
        train,
        x_col='image',
        y_col='label',
        target_size=image_size,
        batch_size=batch_size,
        class_mode='binary',
        shuffle=True
    )

    test_generator = datagen.flow_from_dataframe(
        test,
        x_col='image',
        y_col='label',
        target_size=image_size,
        batch_size=batch_size,
        class_mode='binary',
        shuffle=False
    )

    val_generator = datagen.flow_from_dataframe(
        val,
        x_col='image',
        y_col='label',
        target_size=image_size,
        batch_size=batch_size,
        class_mode='binary',
        shuffle=True
    )

    return train_generator, test_generator, val_generator

# Modeling
def build_model():
    class_num = 1
    model = keras.models.Sequential()
    model.add(keras.layers.Conv2D(filters=32, kernel_size=(3,3),activation=tf.nn.relu,input_shape=(224,224,3)))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.MaxPool2D((2,2)))  
    model.add(keras.layers.Conv2D(filters=64, kernel_size=(3,3),activation=tf.nn.relu)) 
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.MaxPool2D((2,2))) 
    model.add(keras.layers.Dropout(.3)) 
    model.add(keras.layers.Conv2D(filters=128, kernel_size=(3,3),activation=tf.nn.relu))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.MaxPool2D((2,2))) 
    model.add(keras.layers.Dropout(.3)) 
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(256,activation=tf.nn.relu))
    model.add(keras.layers.Dropout(.3)) 
    model.add(keras.layers.Dense(128,activation=tf.nn.relu)) 
    model.add(keras.layers.Dropout(.3)) 
    model.add(keras.layers.Dense(class_num,activation=tf.nn.sigmoid))

    model.compile(optimizer ='adam', loss='binary_crossentropy', metrics=['accuracy'])
    model.summary()
    return model

# Train the Model
def train_model(model, train_generator, val_generator):
    hist = model.fit(train_generator, epochs=10, validation_data=val_generator)
    return hist

# Evaluate the Model
def evaluate_model(model, test_generator):
    loss, accuracy = model.evaluate(test_generator)
    print('Test Loss =', loss)
    print('Test Accuracy =', accuracy)

    y_test = test_generator.classes
    predictions = model.predict(test_generator)
    y_pred = np.where(predictions >= 0.5, 1, 0)
    y_test = np.ravel(y_test)
    y_pred = np.ravel(y_pred)
    df = pd.DataFrame({'Actual': y_test, 'Prediction': y_pred})

    return y_test, y_pred

def plot_confusion_matrix(y_test, y_pred):
    class_names=['Fractured', 'Not Fractured']
    CM = confusion_matrix(y_test,y_pred)
    sns.heatmap(CM, fmt='g', center=True, cbar=False, annot=True, cmap='Blues')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.xticks(ticks=np.arange(len(class_names)) + 0.5, labels=class_names)
    plt.yticks(ticks=np.arange(len(class_names)) + 0.5, labels=class_names)
    plt.title('Confusion Matrix')
    plt.show()

def plot_accuracy_graph(hist):
    plt.plot(hist.history['accuracy'], label='Train Accuracy')
    plt.plot(hist.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Accuracy Graph')
    plt.show()

if __name__ == "__main__":
    # Read data
    train = data('/kaggle/input/bone-fracture/dataset/train')
    test = data('/kaggle/input/bone-fracture/dataset/test')
    val = data('/kaggle/input/bone-fracture/dataset/val')

    # Create data generators
    train_generator, test_generator, val_generator = create_data_generators(train, test, val)

    # Build model
    model = build_model()

    # Train the model
    hist = train_model(model, train_generator, val_generator)

    # Evaluate the model
    y_test, y_pred = evaluate_model(model, test_generator)

    # Plot confusion matrix
    plot_confusion_matrix(y_test, y_pred)

    # Plot accuracy graph
    plot_accuracy_graph(hist)
# Out:
# 2024-03-18 06:20:55.672201: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-18 06:20:55.672339: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-18 06:20:55.799478: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 4097 validated image filenames belonging to 2 classes.
# Found 399 validated image filenames belonging to 2 classes.
# Found 404 validated image filenames belonging to 2 classes.
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 222, 222, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 109, 109, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 52, 52, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │    22,151,424 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,278,593 (84.99 MB)
#  Trainable params: 22,278,145 (84.98 MB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/10
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2024-03-18 06:21:19.455335: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49284: 7.84353, expected 6.92193
# 2024-03-18 06:21:19.455403: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49286: 7.76792, expected 6.84632
# 2024-03-18 06:21:19.455412: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49287: 6.15631, expected 5.23472
# 2024-03-18 06:21:19.455420: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49288: 6.71859, expected 5.797
# 2024-03-18 06:21:19.455428: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49289: 7.43913, expected 6.51753
# 2024-03-18 06:21:19.455436: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49290: 7.1783, expected 6.25671
# 2024-03-18 06:21:19.455444: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49291: 6.06838, expected 5.14679
# 2024-03-18 06:21:19.455452: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49292: 6.24725, expected 5.32565
# 2024-03-18 06:21:19.455460: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49293: 6.19403, expected 5.27243
# 2024-03-18 06:21:19.455467: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49294: 7.10498, expected 6.18338
# 2024-03-18 06:21:19.477212: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[32,32,222,222]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,224,224]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-18 06:21:19.477270: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-18 06:21:19.477278: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-18 06:21:19.477285: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-18 06:21:19.477292: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-18 06:21:19.477309: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-03-18 06:21:20.197047: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49284: 7.84353, expected 6.92193
# 2024-03-18 06:21:20.197114: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49286: 7.76792, expected 6.84632
# 2024-03-18 06:21:20.197123: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49287: 6.15631, expected 5.23472
# 2024-03-18 06:21:20.197131: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49288: 6.71859, expected 5.797
# 2024-03-18 06:21:20.197139: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49289: 7.43913, expected 6.51753
# 2024-03-18 06:21:20.197147: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49290: 7.1783, expected 6.25671
# 2024-03-18 06:21:20.197157: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49291: 6.06838, expected 5.14679
# 2024-03-18 06:21:20.197165: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49292: 6.24725, expected 5.32565
# 2024-03-18 06:21:20.197172: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49293: 6.19403, expected 5.27243
# 2024-03-18 06:21:20.197180: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49294: 7.10498, expected 6.18338
# 2024-03-18 06:21:20.219072: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[32,32,222,222]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,224,224]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-18 06:21:20.219132: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-18 06:21:20.219140: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-18 06:21:20.219147: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-18 06:21:20.219154: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-18 06:21:20.219170: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
#   1/129 ━━━━━━━━━━━━━━━━━━━━ 36:43 17s/step - accuracy: 0.5625 - loss: 1.4826
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1710742888.053453      69 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  43/129 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - accuracy: 0.6089 - loss: 7.1078
# 2024-03-18 06:21:36.447253: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 147863: 4.14435, expected 3.59734
# 2024-03-18 06:21:36.447320: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 148032: 3.73171, expected 3.1847
# 2024-03-18 06:21:36.447330: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 148049: 4.2981, expected 3.75109
# 2024-03-18 06:21:36.447343: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 149297: 4.2275, expected 3.68049
# 2024-03-18 06:21:36.447352: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 149362: 3.89754, expected 3.35053
# 2024-03-18 06:21:36.447360: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 149444: 4.35104, expected 3.80403
# 2024-03-18 06:21:36.447368: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 149482: 4.25819, expected 3.71118
# 2024-03-18 06:21:36.447376: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 149745: 4.45681, expected 3.9098
# 2024-03-18 06:21:36.447384: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 149769: 4.35836, expected 3.81135
# 2024-03-18 06:21:36.447392: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 149850: 4.35677, expected 3.80977
# 2024-03-18 06:21:36.447408: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[1,32,222,222]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,3,224,224]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-18 06:21:36.447416: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-18 06:21:36.447423: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-18 06:21:36.447429: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-18 06:21:36.447436: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-18 06:21:36.447447: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-03-18 06:21:36.500303: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 147863: 4.14435, expected 3.59734
# 2024-03-18 06:21:36.500360: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 148032: 3.73171, expected 3.1847
# 2024-03-18 06:21:36.500369: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 148049: 4.2981, expected 3.75109
# 2024-03-18 06:21:36.500383: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 149297: 4.2275, expected 3.68049
# 2024-03-18 06:21:36.500391: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 149362: 3.89754, expected 3.35053
# 2024-03-18 06:21:36.500399: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 149444: 4.35104, expected 3.80403
# 2024-03-18 06:21:36.500427: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 149482: 4.25819, expected 3.71118
# 2024-03-18 06:21:36.500437: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 149745: 4.45681, expected 3.9098
# 2024-03-18 06:21:36.500447: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 149769: 4.35836, expected 3.81135
# 2024-03-18 06:21:36.500456: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 149850: 4.35677, expected 3.80977
# 2024-03-18 06:21:36.500472: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[1,32,222,222]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,3,224,224]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-18 06:21:36.500480: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-18 06:21:36.500488: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-18 06:21:36.500495: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-18 06:21:36.500502: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-18 06:21:36.500519: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 128/129 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.6438 - loss: 5.0601
# 2024-03-18 06:21:53.481098: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 6.63812, expected 5.86815
# 2024-03-18 06:21:53.481160: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 6.57545, expected 5.80549
# 2024-03-18 06:21:53.481169: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 6.58905, expected 5.81908
# 2024-03-18 06:21:53.481177: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 6.3889, expected 5.61894
# 2024-03-18 06:21:53.481185: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 10: 6.23839, expected 5.46843
# 2024-03-18 06:21:53.481193: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 11: 4.97291, expected 4.20294
# 2024-03-18 06:21:53.481201: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 12: 5.35322, expected 4.58326
# 2024-03-18 06:21:53.481208: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 13: 5.22464, expected 4.45467
# 2024-03-18 06:21:53.481216: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 27: 6.65894, expected 5.88898
# 2024-03-18 06:21:53.481224: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 28: 6.10743, expected 5.33746
# 2024-03-18 06:21:53.495165: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[20,32,222,222]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,3,224,224]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-18 06:21:53.495213: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-18 06:21:53.495222: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-18 06:21:53.495228: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-18 06:21:53.495235: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-18 06:21:53.495250: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-03-18 06:21:53.893049: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 6.63812, expected 5.86815
# 2024-03-18 06:21:53.893109: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 6.57545, expected 5.80549
# 2024-03-18 06:21:53.893118: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 6.58905, expected 5.81908
# 2024-03-18 06:21:53.893126: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 6.3889, expected 5.61894
# 2024-03-18 06:21:53.893134: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 10: 6.23839, expected 5.46843
# 2024-03-18 06:21:53.893142: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 11: 4.97291, expected 4.20294
# 2024-03-18 06:21:53.893149: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 12: 5.35322, expected 4.58326
# 2024-03-18 06:21:53.893157: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 13: 5.22464, expected 4.45467
# 2024-03-18 06:21:53.893165: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 27: 6.65894, expected 5.88898
# 2024-03-18 06:21:53.893172: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 28: 6.10743, expected 5.33746
# 2024-03-18 06:21:53.907623: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[20,32,222,222]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,3,224,224]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-18 06:21:53.907674: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-18 06:21:53.907683: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-18 06:21:53.907690: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-18 06:21:53.907697: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-18 06:21:53.907714: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 44s 211ms/step - accuracy: 0.6444 - loss: 5.0310 - val_accuracy: 0.6980 - val_loss: 4.2849
# Epoch 2/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 72ms/step - accuracy: 0.8189 - loss: 0.9257 - val_accuracy: 0.5124 - val_loss: 7.4395
# Epoch 3/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.8657 - loss: 0.5633 - val_accuracy: 0.7153 - val_loss: 6.5966
# Epoch 4/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.8793 - loss: 0.3499 - val_accuracy: 0.8960 - val_loss: 0.5508
# Epoch 5/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - accuracy: 0.9137 - loss: 0.2739 - val_accuracy: 0.9035 - val_loss: 0.5910
# Epoch 6/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - accuracy: 0.9402 - loss: 0.1828 - val_accuracy: 0.9134 - val_loss: 0.6648
# Epoch 7/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.9446 - loss: 0.1733 - val_accuracy: 0.9728 - val_loss: 0.4899
# Epoch 8/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - accuracy: 0.9631 - loss: 0.1191 - val_accuracy: 0.9728 - val_loss: 0.1761
# Epoch 9/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.9667 - loss: 0.1084 - val_accuracy: 0.9629 - val_loss: 0.5727
# Epoch 10/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - accuracy: 0.9689 - loss: 0.1044 - val_accuracy: 0.9678 - val_loss: 0.3916
# 12/13 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9786 - loss: 0.1001
# 2024-03-18 06:23:27.250060: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49287: 7.61846, expected 6.73536
# 2024-03-18 06:23:27.250121: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49288: 7.75449, expected 6.8714
# 2024-03-18 06:23:27.250136: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49290: 6.77945, expected 5.89635
# 2024-03-18 06:23:27.250148: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49291: 6.42989, expected 5.54679
# 2024-03-18 06:23:27.250160: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49292: 7.06139, expected 6.17829
# 2024-03-18 06:23:27.250169: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49293: 7.03813, expected 6.15504
# 2024-03-18 06:23:27.250179: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49294: 6.38949, expected 5.50639
# 2024-03-18 06:23:27.250189: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49295: 5.37303, expected 4.48993
# 2024-03-18 06:23:27.250200: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49296: 5.97391, expected 5.09081
# 2024-03-18 06:23:27.250210: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49297: 6.19812, expected 5.31502
# 2024-03-18 06:23:27.260830: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[15,32,222,222]{3,2,1,0}, u8[0]{0}) custom-call(f32[15,3,224,224]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-18 06:23:27.260883: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-18 06:23:27.260895: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-18 06:23:27.260912: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-18 06:23:27.260922: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-18 06:23:27.260943: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-03-18 06:23:27.536897: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49287: 7.61846, expected 6.73536
# 2024-03-18 06:23:27.536961: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49288: 7.75449, expected 6.8714
# 2024-03-18 06:23:27.536976: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49290: 6.77945, expected 5.89635
# 2024-03-18 06:23:27.536986: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49291: 6.42989, expected 5.54679
# 2024-03-18 06:23:27.537000: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49292: 7.06139, expected 6.17829
# 2024-03-18 06:23:27.537016: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49293: 7.03813, expected 6.15504
# 2024-03-18 06:23:27.537030: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49294: 6.38949, expected 5.50639
# 2024-03-18 06:23:27.537041: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49295: 5.37303, expected 4.48993
# 2024-03-18 06:23:27.537052: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49296: 5.97391, expected 5.09081
# 2024-03-18 06:23:27.537063: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49297: 6.19812, expected 5.31502
# 2024-03-18 06:23:27.548291: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[15,32,222,222]{3,2,1,0}, u8[0]{0}) custom-call(f32[15,3,224,224]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-18 06:23:27.548347: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-18 06:23:27.548360: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-18 06:23:27.548371: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-18 06:23:27.548380: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-18 06:23:27.548401: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 265ms/step - accuracy: 0.9720 - loss: 0.1865
# Test Loss = 0.7047695517539978
# Test Accuracy = 0.932330846786499
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step

# %%
import os 
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import keras 
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.layers import Dense, Flatten, Dropout
from keras.models import Model

# Read Data
def data(dataset_path):
    images = []
    labels = []
    for subfolder in os.listdir(dataset_path):
        subfolder_path = os.path.join(dataset_path, subfolder)
        if not os.path.isdir(subfolder_path):
            continue
        for image_filename in os.listdir(subfolder_path):
            if image_filename.endswith(".jpg"):
                image_path = os.path.join(subfolder_path, image_filename)
                images.append(image_path)
                labels.append(subfolder)
    df = pd.DataFrame({'image': images, 'label': labels})
    return df

# Create data generators
def create_data_generators(train, test, val):
    image_size = (224, 224)
    batch_size = 32
    datagen = ImageDataGenerator(rescale=1./255)

    train_generator = datagen.flow_from_dataframe(
        train,
        x_col='image',
        y_col='label',
        target_size=image_size,
        batch_size=batch_size,
        class_mode='binary',
        shuffle=True
    )

    test_generator = datagen.flow_from_dataframe(
        test,
        x_col='image',
        y_col='label',
        target_size=image_size,
        batch_size=batch_size,
        class_mode='binary',
        shuffle=False
    )

    val_generator = datagen.flow_from_dataframe(
        val,
        x_col='image',
        y_col='label',
        target_size=image_size,
        batch_size=batch_size,
        class_mode='binary',
        shuffle=True
    )

    return train_generator, test_generator, val_generator

# Build VGG-16 model
def build_model():
    # Load the VGG-16 model pre-trained on ImageNet data
    base_model = keras.applications.VGG16(input_shape=(224, 224, 3), weights='imagenet', include_top=False)

    # Freeze the layers in the base VGG-16 model
    for layer in base_model.layers:
        layer.trainable = False

    # Adding custom layers for classification
    x = Flatten()(base_model.output)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.5)(x)              
    predictions = Dense(1, activation='sigmoid')(x)  # Changed to binary classification

    # Creating the final model
    model = Model(inputs=base_model.input, outputs=predictions)

    # Compile the model
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    model.summary()
    return model

# Train the Model
def train_model(model, train_generator, val_generator):
    hist = model.fit(train_generator, epochs=10, validation_data=val_generator)
    return hist

# Evaluate the Model
def evaluate_model(model, test_generator):
    loss, accuracy = model.evaluate(test_generator)
    print('Test Loss =', loss)
    print('Test Accuracy =', accuracy)

    y_test = test_generator.classes
    predictions = model.predict(test_generator)
    y_pred = np.where(predictions >= 0.5, 1, 0)
    y_test = np.ravel(y_test)
    y_pred = np.ravel(y_pred)
    df = pd.DataFrame({'Actual': y_test, 'Prediction': y_pred})
    return y_test, y_pred

def plot_confusion_matrix(y_true, y_pred):
    class_names=['Fractured', 'Not Fractured']
    CM = confusion_matrix(y_true, y_pred)
    sns.heatmap(CM, fmt='g', center=True, cbar=False, annot=True, cmap='Blues')
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    plt.xticks(ticks=np.arange(len(class_names)), labels=class_names)
    plt.yticks(ticks=np.arange(len(class_names)), labels=class_names)
    plt.title('Confusion Matrix')
    plt.show()

def plot_accuracy_graph(hist):
    plt.plot(hist.history['accuracy'], label='Train Accuracy')
    plt.plot(hist.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Accuracy over Epochs')
    plt.show()

if __name__ == "__main__":
    # Read data
    train = data('/kaggle/input/bone-fracture/dataset/train')
    test = data('/kaggle/input/bone-fracture/dataset/test')
    val = data('/kaggle/input/bone-fracture/dataset/val')

    # Create data generators
    train_generator, test_generator, val_generator = create_data_generators(train, test, val)

    # Build VGG-16 model
    model = build_model()

    # Train the model
    hist = train_model(model, train_generator, val_generator)

    # Evaluate the model
    y_test, y_pred_16 = evaluate_model(model, test_generator)

    # Plot confusion matrix
    plot_confusion_matrix(y_test, y_pred)

    # Plot accuracy graph
    plot_accuracy_graph(hist)
# Out:
# Found 4097 validated image filenames belonging to 2 classes.
# Found 399 validated image filenames belonging to 2 classes.
# Found 404 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1024)           │    25,691,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │         1,025 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 40,406,849 (154.14 MB)
#  Trainable params: 25,692,161 (98.01 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)
# Epoch 1/10
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2024-03-18 06:23:35.421367: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 4.63498, expected 3.85968
# 2024-03-18 06:23:35.421433: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 6.55784, expected 5.78254
# 2024-03-18 06:23:35.421443: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 6.61282, expected 5.83752
# 2024-03-18 06:23:35.421451: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 6.34499, expected 5.56968
# 2024-03-18 06:23:35.421459: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 6.25159, expected 5.47629
# 2024-03-18 06:23:35.421467: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 5.43964, expected 4.66434
# 2024-03-18 06:23:35.421474: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 6.54333, expected 5.76803
# 2024-03-18 06:23:35.421482: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 10: 5.76049, expected 4.98519
# 2024-03-18 06:23:35.421490: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 11: 5.33632, expected 4.56101
# 2024-03-18 06:23:35.421498: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 12: 4.04081, expected 3.2655
# 2024-03-18 06:23:35.466378: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[32,64,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,224,224]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-18 06:23:35.466439: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-18 06:23:35.466448: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-18 06:23:35.466455: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-18 06:23:35.466462: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-18 06:23:35.466479: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-03-18 06:23:36.576788: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 4.63498, expected 3.85968
# 2024-03-18 06:23:36.576857: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 6.55784, expected 5.78254
# 2024-03-18 06:23:36.576866: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 6.61282, expected 5.83752
# 2024-03-18 06:23:36.576874: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 6.34499, expected 5.56968
# 2024-03-18 06:23:36.576882: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 6.25159, expected 5.47629
# 2024-03-18 06:23:36.576890: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 5.43964, expected 4.66434
# 2024-03-18 06:23:36.576898: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 6.54333, expected 5.76803
# 2024-03-18 06:23:36.576905: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 10: 5.76049, expected 4.98519
# 2024-03-18 06:23:36.576913: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 11: 5.33632, expected 4.56101
# 2024-03-18 06:23:36.576921: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 12: 4.04081, expected 3.2655
# 2024-03-18 06:23:36.621579: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[32,64,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,224,224]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-18 06:23:36.621644: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-18 06:23:36.621652: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-18 06:23:36.621659: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-18 06:23:36.621666: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-18 06:23:36.621683: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
#  58/129 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.6396 - loss: 2.7779
# 2024-03-18 06:23:56.829832: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 4.42855, expected 3.64542
# 2024-03-18 06:23:56.829887: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 5.87036, expected 5.08723
# 2024-03-18 06:23:56.829907: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 6.04003, expected 5.2569
# 2024-03-18 06:23:56.829921: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 6.22034, expected 5.43722
# 2024-03-18 06:23:56.829931: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 4.90026, expected 4.11714
# 2024-03-18 06:23:56.829943: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 5.21068, expected 4.42756
# 2024-03-18 06:23:56.829953: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 5.92061, expected 5.13748
# 2024-03-18 06:23:56.829964: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 5.34421, expected 4.56109
# 2024-03-18 06:23:56.829975: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 4.55002, expected 3.76689
# 2024-03-18 06:23:56.829987: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 5.10735, expected 4.32423
# 2024-03-18 06:23:56.830011: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[1,64,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,3,224,224]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-18 06:23:56.830025: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-18 06:23:56.830035: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-18 06:23:56.830045: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-18 06:23:56.830055: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-18 06:23:56.830073: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-03-18 06:23:56.873065: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 4.42855, expected 3.64542
# 2024-03-18 06:23:56.873128: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 5.87036, expected 5.08723
# 2024-03-18 06:23:56.873143: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 6.04003, expected 5.2569
# 2024-03-18 06:23:56.873156: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 6.22034, expected 5.43722
# 2024-03-18 06:23:56.873172: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 4.90026, expected 4.11714
# 2024-03-18 06:23:56.873187: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 5.21068, expected 4.42756
# 2024-03-18 06:23:56.873197: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 5.92061, expected 5.13748
# 2024-03-18 06:23:56.873209: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 5.34421, expected 4.56109
# 2024-03-18 06:23:56.873219: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 4.55002, expected 3.76689
# 2024-03-18 06:23:56.873229: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 5.10735, expected 4.32423
# 2024-03-18 06:23:56.873254: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[1,64,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,3,224,224]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-18 06:23:56.873269: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-18 06:23:56.873281: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-18 06:23:56.873292: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-18 06:23:56.873303: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-18 06:23:56.873320: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.7422 - loss: 1.7352
# 2024-03-18 06:24:07.166353: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50176: 3.79983, expected 3.15789
# 2024-03-18 06:24:07.166420: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50177: 5.13466, expected 4.49272
# 2024-03-18 06:24:07.166435: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50178: 4.78155, expected 4.13961
# 2024-03-18 06:24:07.166449: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50179: 4.88295, expected 4.24101
# 2024-03-18 06:24:07.166462: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50180: 4.73279, expected 4.09085
# 2024-03-18 06:24:07.166479: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50181: 4.69943, expected 4.05749
# 2024-03-18 06:24:07.166489: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50182: 4.1975, expected 3.55556
# 2024-03-18 06:24:07.166500: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50183: 4.73806, expected 4.09612
# 2024-03-18 06:24:07.166511: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50184: 4.63452, expected 3.99258
# 2024-03-18 06:24:07.166521: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50185: 4.5168, expected 3.87486
# 2024-03-18 06:24:07.194810: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[20,64,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,3,224,224]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-18 06:24:07.194873: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-18 06:24:07.194888: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-18 06:24:07.194900: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-18 06:24:07.194912: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-18 06:24:07.194933: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-03-18 06:24:07.901403: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50176: 3.79983, expected 3.15789
# 2024-03-18 06:24:07.901467: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50177: 5.13466, expected 4.49272
# 2024-03-18 06:24:07.901488: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50178: 4.78155, expected 4.13961
# 2024-03-18 06:24:07.901498: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50179: 4.88295, expected 4.24101
# 2024-03-18 06:24:07.901507: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50180: 4.73279, expected 4.09085
# 2024-03-18 06:24:07.901516: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50181: 4.69943, expected 4.05749
# 2024-03-18 06:24:07.901528: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50182: 4.1975, expected 3.55556
# 2024-03-18 06:24:07.901547: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50183: 4.73806, expected 4.09612
# 2024-03-18 06:24:07.901577: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50184: 4.63452, expected 3.99258
# 2024-03-18 06:24:07.901589: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 50185: 4.5168, expected 3.87486
# 2024-03-18 06:24:07.929767: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[20,64,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,3,224,224]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-18 06:24:07.929833: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-18 06:24:07.929848: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-18 06:24:07.929860: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-18 06:24:07.929874: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-18 06:24:07.929897: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 46s 202ms/step - accuracy: 0.7432 - loss: 1.7268 - val_accuracy: 0.9827 - val_loss: 0.1974
# Epoch 2/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - accuracy: 0.9879 - loss: 0.0470 - val_accuracy: 0.9802 - val_loss: 0.1679
# Epoch 3/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - accuracy: 0.9798 - loss: 102.9099 - val_accuracy: 0.9752 - val_loss: 0.2559
# Epoch 4/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - accuracy: 0.8774 - loss: 0.7040 - val_accuracy: 0.9950 - val_loss: 0.0762
# Epoch 5/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - accuracy: 0.8230 - loss: 6903.5669 - val_accuracy: 0.9530 - val_loss: 3.3725
# Epoch 6/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 80ms/step - accuracy: 0.8937 - loss: 1453.4381 - val_accuracy: 0.9851 - val_loss: 0.8022
# Epoch 7/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.7764 - loss: 2440.6736 - val_accuracy: 0.9653 - val_loss: 4.3689
# Epoch 8/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - accuracy: 0.8076 - loss: 7.6920 - val_accuracy: 0.9777 - val_loss: 1.1027
# Epoch 9/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - accuracy: 0.8567 - loss: 5.6100 - val_accuracy: 0.9827 - val_loss: 2.3923
# Epoch 10/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - accuracy: 0.8976 - loss: 3.5043 - val_accuracy: 0.9876 - val_loss: 3.1822
# 12/13 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9834 - loss: 0.3088
# 2024-03-18 06:25:55.195202: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 4.00564, expected 3.36194
# 2024-03-18 06:25:55.195268: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 5.21235, expected 4.56865
# 2024-03-18 06:25:55.195277: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 10: 5.39965, expected 4.75595
# 2024-03-18 06:25:55.195285: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 11: 5.25668, expected 4.61298
# 2024-03-18 06:25:55.195293: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 12: 3.55266, expected 2.90896
# 2024-03-18 06:25:55.195301: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 13: 4.84224, expected 4.19854
# 2024-03-18 06:25:55.195308: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 29: 4.23174, expected 3.58804
# 2024-03-18 06:25:55.195316: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 30: 4.7388, expected 4.0951
# 2024-03-18 06:25:55.195324: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 31: 4.74565, expected 4.10195
# 2024-03-18 06:25:55.195331: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 42: 5.39528, expected 4.75158
# 2024-03-18 06:25:55.216230: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[15,64,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[15,3,224,224]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-18 06:25:55.216292: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-18 06:25:55.216301: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-18 06:25:55.216308: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-18 06:25:55.216315: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-18 06:25:55.216332: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-03-18 06:25:55.721782: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 4.00564, expected 3.36194
# 2024-03-18 06:25:55.721842: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 5.21235, expected 4.56865
# 2024-03-18 06:25:55.721861: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 10: 5.39965, expected 4.75595
# 2024-03-18 06:25:55.721875: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 11: 5.25668, expected 4.61298
# 2024-03-18 06:25:55.721886: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 12: 3.55266, expected 2.90896
# 2024-03-18 06:25:55.721897: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 13: 4.84224, expected 4.19854
# 2024-03-18 06:25:55.721908: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 29: 4.23174, expected 3.58804
# 2024-03-18 06:25:55.721918: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 30: 4.7388, expected 4.0951
# 2024-03-18 06:25:55.721929: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 31: 4.74565, expected 4.10195
# 2024-03-18 06:25:55.721940: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 42: 5.39528, expected 4.75158
# 2024-03-18 06:25:55.745167: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[15,64,224,224]{3,2,1,0}, u8[0]{0}) custom-call(f32[15,3,224,224]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-18 06:25:55.745227: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-18 06:25:55.745241: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-18 06:25:55.745257: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-18 06:25:55.745267: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-18 06:25:55.745287: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 722ms/step - accuracy: 0.9840 - loss: 0.2921
# Test Loss = 0.19190655648708344
# Test Accuracy = 0.9874686598777771
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step

# %%
import os 
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import keras 
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import confusion_matrix, classification_report

# Read Data
def data(dataset_path):
    images = []
    labels = []
    for subfolder in os.listdir(dataset_path):
        subfolder_path = os.path.join(dataset_path, subfolder)
        if not os.path.isdir(subfolder_path):
            continue
        for image_filename in os.listdir(subfolder_path):
            if image_filename.endswith(".jpg"):
                image_path = os.path.join(subfolder_path, image_filename)
                images.append(image_path)
                labels.append(subfolder)
    df = pd.DataFrame({'image': images, 'label': labels})
    return df

# Create data generators
def create_data_generators(train, test, val):
    image_size = (224, 224)
    batch_size = 32
    datagen = ImageDataGenerator(rescale=1./255)

    train_generator = datagen.flow_from_dataframe(
        train,
        x_col='image',
        y_col='label',
        target_size=image_size,
        batch_size=batch_size,
        class_mode='binary',
        shuffle=True
    )

    test_generator = datagen.flow_from_dataframe(
        test,
        x_col='image',
        y_col='label',
        target_size=image_size,
        batch_size=batch_size,
        class_mode='binary',
        shuffle=False
    )

    val_generator = datagen.flow_from_dataframe(
        val,
        x_col='image',
        y_col='label',
        target_size=image_size,
        batch_size=batch_size,
        class_mode='binary',
        shuffle=True
    )

    return train_generator, test_generator, val_generator

# Build VGG-19 model
def build_model():
    # Load the VGG-19 model pre-trained on ImageNet data
    base_model = keras.applications.VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

    # Freeze the layers in the base VGG-19 model
    for layer in base_model.layers:
        layer.trainable = False

    # Adding custom layers for classification
    x = Flatten()(base_model.output)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)                  
    predictions = Dense(1, activation='sigmoid')(x)  # Changed to binary classification

    # Creating the final model
    model = Model(inputs=base_model.input, outputs=predictions)

    # Compile the model
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    model.summary()
    return model

# Train the Model
def train_model(model, train_generator, val_generator):
    hist = model.fit(train_generator, epochs=10, validation_data=val_generator)
    return hist

# Evaluate the Model
def evaluate_model(model, test_generator):
    loss, accuracy = model.evaluate(test_generator)
    print('Test Loss =', loss)
    print('Test Accuracy =', accuracy)

    y_test = test_generator.classes
    predictions = model.predict(test_generator)
    y_pred = np.where(predictions >= 0.5, 1, 0)
    y_test = np.ravel(y_test)
    y_pred = np.ravel(y_pred)
    df = pd.DataFrame({'Actual': y_test, 'Prediction': y_pred})
    return y_test, y_pred

def plot_confusion_matrix(y_true, y_pred):
    class_names=['Fractured', 'Not Fractured']
    CM = confusion_matrix(y_true, y_pred)
    sns.heatmap(CM, fmt='g', center=True, cbar=False, annot=True, cmap='Blues')
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    plt.xticks(ticks=np.arange(len(class_names)), labels=class_names)
    plt.yticks(ticks=np.arange(len(class_names)), labels=class_names)
    plt.title('Confusion Matrix')
    plt.show()

def plot_accuracy_graph(hist):
    plt.plot(hist.history['accuracy'], label='Train Accuracy')
    plt.plot(hist.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Accuracy over Epochs')
    plt.show()

if __name__ == "__main__":
    # Read data
    train = data('/kaggle/input/bone-fracture/dataset/train')
    test = data('/kaggle/input/bone-fracture/dataset/test')
    val = data('/kaggle/input/bone-fracture/dataset/val')

    # Create data generators
    train_generator, test_generator, val_generator = create_data_generators(train, test, val)

    # Build VGG-19 model
    model = build_model()

    # Train the model
    hist = train_model(model, train_generator, val_generator)

    # Evaluate the model
    y_test, y_pred_19 = evaluate_model(model, test_generator)

    # Plot confusion matrix
    plot_confusion_matrix(y_test, y_pred)

    # Plot accuracy graph
    plot_accuracy_graph(hist)
# Out:
# Found 4097 validated image filenames belonging to 2 classes.
# Found 399 validated image filenames belonging to 2 classes.
# Found 404 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_20"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv4 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv4 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv4 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 256)            │     6,422,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 26,447,425 (100.89 MB)
#  Trainable params: 6,423,041 (24.50 MB)
#  Non-trainable params: 20,024,384 (76.39 MB)
# Epoch 1/10
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 20s 118ms/step - accuracy: 0.7265 - loss: 1.2433 - val_accuracy: 0.9579 - val_loss: 0.1631
# Epoch 2/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 12s 88ms/step - accuracy: 0.9765 - loss: 0.0855 - val_accuracy: 0.9851 - val_loss: 0.1612
# Epoch 3/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 12s 88ms/step - accuracy: 0.9935 - loss: 0.0308 - val_accuracy: 0.9876 - val_loss: 0.2058
# Epoch 4/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 21s 89ms/step - accuracy: 0.9976 - loss: 0.0153 - val_accuracy: 0.9975 - val_loss: 0.0159
# Epoch 5/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 12s 88ms/step - accuracy: 0.9971 - loss: 0.0148 - val_accuracy: 0.9901 - val_loss: 0.2582
# Epoch 6/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 12s 88ms/step - accuracy: 0.9965 - loss: 0.0138 - val_accuracy: 0.9827 - val_loss: 0.3190
# Epoch 7/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 21s 88ms/step - accuracy: 0.9969 - loss: 0.0124 - val_accuracy: 0.9901 - val_loss: 0.0876
# Epoch 8/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 12s 88ms/step - accuracy: 0.9982 - loss: 0.0078 - val_accuracy: 0.9851 - val_loss: 0.2024
# Epoch 9/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 12s 88ms/step - accuracy: 0.6741 - loss: 2262.5557 - val_accuracy: 0.9208 - val_loss: 1.8178
# Epoch 10/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 12s 88ms/step - accuracy: 0.7861 - loss: 9.9673 - val_accuracy: 0.9653 - val_loss: 3.3458
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - accuracy: 0.9574 - loss: 0.8373
# Test Loss = 0.6860523223876953
# Test Accuracy = 0.969924807548523
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step

# %%
# Calculate test accuracy for each model
accuracy_vgg16 = np.sum(y_test == y_pred_16) / len(y_test) * 100
accuracy_vgg19 = np.sum(y_test == y_pred_19) / len(y_test) * 100
accuracy_custom_cnn = np.sum(y_test == y_pred) / len(y_test) * 100

# Plot the test accuracies
models = ['VGG-16', 'VGG-19', 'Custom CNN']
accuracies = [accuracy_vgg16, accuracy_vgg19, accuracy_custom_cnn]
plt.figure(figsize=(10, 6))
plt.bar(models, accuracies, color=['blue', 'green', 'orange'])
plt.xlabel('Model')
plt.ylabel('Test Accuracy (%)')
plt.title('Comparison of Test Accuracy Between Models')
plt.ylim(0, 100)
plt.show()
